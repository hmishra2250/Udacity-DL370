# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE
import itertools

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
#del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Variables description:
#
# * words - initial list of words
#
# * data - words converted to indices
#
# * dictionary - mapping of most common words from vocab to indices
#
# * reverse_dictionary - mapping from indices to word
#
# * count - var storing word counts for 50k most common words

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'a', 'originated', 'term', 'term', 'originated', 'of', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
  print(similarity.get_shape().as_list())
# Out:
# [16, 50000]

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.546543
# Nearest to years: blasted, soon, lepidoptera, malcolm, mana, expecting, maniac, isoleucine,
# Nearest to state: vowels, chet, apparitions, nerve, impartial, representational, wafer, brushes,
# Nearest to use: uzi, callers, humor, transcended, abbe, polycrates, magnifying, arnaz,
# Nearest to who: zahn, robe, bethany, portmanteau, overload, jim, tz, defaulted,
# Nearest to it: additionally, thread, undergoes, corresponding, rence, consented, pita, shooting,
# Nearest to some: acker, lengthening, origins, capybaras, kenyon, choir, adidas, cascading,
# Nearest to there: rope, abyssinian, eusebio, wondered, fullerene, robbie, rourke, glucocorticoids,
# Nearest to i: chirality, bagpuss, fuse, cisco, catchphrase, prescription, ubu, pickford,
# Nearest to that: famers, parrot, vindicated, paleontology, leq, coats, rocketry, sybase,
# Nearest to other: spine, contest, toward, pki, amphitheatre, nagarjuna, salt, contesting,
# Nearest to was: uv, entertain, evaluating, parrot, chiaroscuro, lombardi, booker, updating,
# Nearest to a: endless, algerian, aaron, fridtjof, nis, alliaceae, listerine, beasts,
# Nearest to see: roasted, geschichte, primate, abdicate, rescuing, seanad, reduplication, theology,
# Nearest to in: colonels, beauregard, believers, limewire, yetzirah, preprint, americana, creates,
# Nearest to after: operands, homme, edgar, basin, pashtun, oranges, additionally, cel,
# Nearest to be: undp, unsafe, notable, conclave, confidentiality, orbison, tax, broadened,
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-51-3446420b5935> in <module>()
#       9       batch_size, num_skips, skip_window)
#      10     feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
# ---> 11     _, l = session.run([optimizer, loss], feed_dict=feed_dict)
#      12     average_loss += l
#      13     if step % 2000 == 0:
#
# /home/him/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/him/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# /home/him/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /home/him/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1020   def _do_call(self, fn, *args):
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#    1024       message = compat.as_text(e.message)
#
# /home/him/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1002         return tf_session.TF_Run(session, options,
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#    1006     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
num_points = 1000

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=10000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
words = read_data(filename)
print('Data size %d' % len(words))

vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
# Out:
# Data size 17005207
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %%
data_index = 0

def generate_batch(batch_size, window):
  global data_index
  span = 2 * window + 1 # [ length of window for CBOW ]
  batch = np.ndarray(shape=(batch_size, span-1), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    target = window  # target label at the center of the buffer
    targets_to_avoid = [ window ]
    batch[i] = list(itertools.islice(buffer,0,target)) + list(itertools.islice(buffer, target+1, span))
    labels[i] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for window in [1, 2]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, window=window)
    print('\nwith windows = %d \n' % (window), end='')
    print('    batch:\n',end='')
    dix = 0
    for bi in batch:
        for ele in bi:
            print('\t',reverse_dictionary[ele],' ',end='')
        print('\t','------->  ',reverse_dictionary[labels[dix][0]])
        print('\n')
        dix += 1
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with windows = 1
#     batch:
# 	 anarchism  	 as  	 ------->   originated
#
#
# 	 originated  	 a  	 ------->   as
#
#
# 	 as  	 term  	 ------->   a
#
#
# 	 a  	 of  	 ------->   term
#
#
# 	 term  	 abuse  	 ------->   of
#
#
# 	 of  	 first  	 ------->   abuse
#
#
# 	 abuse  	 used  	 ------->   first
#
#
# 	 first  	 against  	 ------->   used
#
#
#
# with windows = 2
#     batch:
# 	 anarchism  	 originated  	 a  	 term  	 ------->   as
#
#
# 	 originated  	 as  	 term  	 of  	 ------->   a
#
#
# 	 as  	 a  	 of  	 abuse  	 ------->   term
#
#
# 	 a  	 term  	 abuse  	 first  	 ------->   of
#
#
# 	 term  	 of  	 first  	 used  	 ------->   abuse
#
#
# 	 of  	 abuse  	 used  	 against  	 ------->   first
#
#
# 	 abuse  	 first  	 against  	 early  	 ------->   used
#
#
# 	 first  	 used  	 early  	 working  	 ------->   against

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
window = 1 # How many words to consider left and right.
span = 2*window + 1 #Total span of window
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, span-1])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  print(embed.get_shape().as_list())
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=tf.reduce_sum(embed, axis=1),
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
  print(similarity.get_shape().as_list())
# Out:
# [128, 2, 128]
# [16, 50000]

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.098124
# Nearest to while: subgenus, railway, bindusara, personality, savoy, occuring, bay, plural,
# Nearest to by: villas, acceded, preserves, satire, germanium, deactivated, ulyanov, overflow,
# Nearest to see: sparing, referees, brilliant, angevin, joachim, hoofed, baryogenesis, anglorum,
# Nearest to an: porfirio, bodhisattva, elaborate, endeavored, crumbs, cdp, dickson, solemnly,
# Nearest to when: xun, waka, ramirez, crisis, simulated, ligny, auctions, nejd,
# Nearest to into: ignore, hails, dragging, fishers, sick, mersenne, gibb, gana,
# Nearest to one: workplaces, anger, electroconvulsive, ostrava, acquisitions, javanese, sinhalese, economically,
# Nearest to two: embattled, dockyard, chel, clad, astrometry, selberg, goldwyn, sarcophagus,
# Nearest to more: orb, shamash, enslaved, dodecanese, marcian, scrape, intimately, akc,
# Nearest to be: ain, buddhism, poul, oration, fabian, intensely, mervyn, fleece,
# Nearest to had: virulent, ontario, necessitate, deporting, marko, discouraged, mortals, snatch,
# Nearest to only: hypnosis, objectively, oscillation, xry, zquez, impassioned, mostar, sacr,
# Nearest to as: aon, ligands, avenues, anacletus, fournier, tides, historicist, sandro,
# Nearest to if: paste, crochet, outskirts, syrian, bethune, fay, gorbachev, philips,
# Nearest to been: caesarea, ashore, noa, gro, transmitters, chiefdoms, bahamas, korner,
# Nearest to often: murder, overthrows, promoted, antonine, govt, ballistic, locative, diabetic,
# Average loss at step 2000: 4.093653
# Average loss at step 4000: 3.560582
# Average loss at step 6000: 3.381284
# Average loss at step 8000: 3.245003
# Average loss at step 10000: 3.176938
# Nearest to while: railway, occuring, subgenus, since, plural, soar, ruling, relied,
# Nearest to by: ulyanov, vre, datagram, figurehead, arlington, rea, soaking, niger,
# Nearest to see: campania, plato, copley, referees, brilliant, acquittal, lech, include,
# Nearest to an: flutter, roofed, bodhisattva, mayo, calvert, kylie, legislated, newborn,
# Nearest to when: elway, reactivity, where, against, castor, chromosomal, inclinations, ldots,
# Nearest to into: from, compulsion, hails, ced, gill, dragging, plasmid, mersenne,
# Nearest to one: eight, seven, four, two, three, six, nine, five,
# Nearest to two: three, four, five, eight, six, seven, nine, zero,
# Nearest to more: less, most, orb, dodecanese, rather, incrimination, specific, enslaved,
# Nearest to be: have, been, was, forma, were, transfusions, take, alfaro,
# Nearest to had: has, have, was, were, never, retired, challenges, having,
# Nearest to only: caesium, gimmicks, matic, unreliable, salutation, not, always, nanny,
# Nearest to as: hwv, preseason, beloved, volkssturm, outcasts, lucrative, interlisp, tienne,
# Nearest to if: philips, stems, receives, plebs, moot, paste, mlb, paleontologist,
# Nearest to been: be, were, eloped, innovated, become, noa, was, bahamas,
# Nearest to often: now, also, generally, sometimes, usually, never, juanita, murder,
# Average loss at step 12000: 3.196838
# Average loss at step 14000: 3.149350
# Average loss at step 16000: 3.178132
# Average loss at step 18000: 3.128163
# Average loss at step 20000: 2.990946
# Nearest to while: although, showed, relied, railway, since, are, occuring, retriever,
# Nearest to by: vre, safeguarding, during, ulyanov, rosenberg, editing, druid, bilbo,
# Nearest to see: include, gardiner, buses, transformations, endothermy, sooner, copious, boomed,
# Nearest to an: flutter, roofed, clipperton, daime, harpists, forwards, newborn, blob,
# Nearest to when: if, where, elway, after, as, though, since, kilimanjaro,
# Nearest to into: from, through, ced, across, adf, pratyeka, hails, back,
# Nearest to one: eight, four, two, six, seven, five, three, zero,
# Nearest to two: three, six, four, five, seven, eight, one, zero,
# Nearest to more: less, most, rather, very, orb, incrimination, already, misfits,
# Nearest to be: have, been, become, being, is, were, refer, forma,
# Nearest to had: has, have, was, never, having, moqed, were, postgraduate,
# Nearest to only: always, circumcised, persist, wirth, either, caesium, molecules, unreliable,
# Nearest to as: basel, when, preseason, risorgimento, rasputin, volkssturm, japh, quotes,
# Nearest to if: when, for, plebs, though, keralite, so, drones, concede,
# Nearest to been: become, be, were, was, eloped, innovated, balaguer, containment,
# Nearest to often: sometimes, usually, commonly, generally, now, also, not, never,
# Average loss at step 22000: 3.076721
# Average loss at step 24000: 3.028737
# Average loss at step 26000: 2.998681
# Average loss at step 28000: 3.026793
# Average loss at step 30000: 3.005756
# Nearest to while: although, when, however, relied, pelts, after, since, before,
# Nearest to by: acculturation, was, ard, during, vre, safeguarding, rea, has,
# Nearest to see: include, but, sooner, transformations, blockbuster, boomed, ima, fleshy,
# Nearest to an: fujiko, flutter, blob, electrolytes, nic, clipperton, polls, dieppe,
# Nearest to when: if, after, although, while, before, where, though, because,
# Nearest to into: through, from, across, within, adf, around, out, over,
# Nearest to one: two, six, five, three, four, seven, nine, zero,
# Nearest to two: three, six, four, five, seven, nine, one, eight,
# Nearest to more: less, rather, most, very, other, already, too, orb,
# Nearest to be: been, being, was, become, have, is, xena, cause,
# Nearest to had: has, have, was, having, were, never, lugh, gave,
# Nearest to only: always, nanny, traditionally, briand, either, mommy, scratched, tonic,
# Nearest to as: toltec, manitou, erowid, preseason, hacked, blaise, pacemakers, beyond,
# Nearest to if: when, though, where, since, although, keralite, plebs, forthcoming,
# Nearest to been: become, be, was, were, innovated, eloped, begun, drawer,
# Nearest to often: sometimes, usually, now, commonly, generally, frequently, also, still,
# Average loss at step 32000: 2.825632
# Average loss at step 34000: 2.959955
# Average loss at step 36000: 2.949367
# Average loss at step 38000: 2.937659
# Average loss at step 40000: 2.925695
# Nearest to while: although, when, and, during, though, divisional, despite, after,
# Nearest to by: through, kittyhawk, heliogabalus, oldies, having, rosenberg, during, onto,
# Nearest to see: include, references, sooner, copley, oligarchy, boomed, hamza, childbearing,
# Nearest to an: clipperton, flutter, blob, fujiko, legislated, raids, harpists, convents,
# Nearest to when: if, before, after, while, although, though, where, because,
# Nearest to into: through, from, across, within, with, adf, welt, around,
# Nearest to one: two, six, seven, four, eight, three, five, hera,
# Nearest to two: three, five, four, six, seven, eight, one, zero,
# Nearest to more: less, most, rather, very, quite, orb, larger, courting,
# Nearest to be: been, being, become, have, is, refer, contain, remain,
# Nearest to had: has, have, was, having, were, never, sangha, lugh,
# Nearest to only: always, either, credited, briand, first, game, leinster, unofficially,
# Nearest to as: bova, bellerophon, symbolics, fsf, gregers, underestimated, zy, abacus,
# Nearest to if: when, though, where, since, because, before, temp, receives,
# Nearest to been: become, be, was, were, begun, innovated, eloped, maggie,
# Nearest to often: usually, sometimes, commonly, now, generally, typically, frequently, still,
# Average loss at step 42000: 2.956165
# Average loss at step 44000: 2.954299
# Average loss at step 46000: 2.911755
# Average loss at step 48000: 2.868522
# Average loss at step 50000: 2.846169
# Nearest to while: although, when, including, though, during, are, before, but,
# Nearest to by: during, when, onto, through, after, against, easterly, using,
# Nearest to see: include, known, hamza, but, includes, boomed, ima, references,
# Nearest to an: another, clipperton, flutter, dieppe, legislated, blob, fujiko, electrolytes,
# Nearest to when: if, after, before, while, where, though, although, during,
# Nearest to into: through, from, across, within, adf, around, under, onto,
# Nearest to one: two, four, seven, eight, six, zero, three, five,
# Nearest to two: three, four, six, five, seven, eight, nine, one,
# Nearest to more: less, most, very, rather, larger, quite, higher, faster,
# Nearest to be: being, been, have, become, is, are, xena, refer,
# Nearest to had: has, have, was, having, were, never, gave, sangha,
# Nearest to only: always, either, leinster, credited, regulators, never, even, mescaline,
# Nearest to as: preseason, zy, bellerophon, like, acr, falsificationism, rec, volkssturm,
# Nearest to if: when, though, where, since, because, before, unless, while,
# Nearest to been: become, be, already, remained, recently, was, begun, innovated,
# Nearest to often: usually, sometimes, commonly, generally, now, frequently, typically, widely,
# Average loss at step 52000: 2.884676
# Average loss at step 54000: 2.865050
# Average loss at step 56000: 2.857436
# Average loss at step 58000: 2.747512
# Average loss at step 60000: 2.827236
# Nearest to while: although, when, though, before, however, unlike, divisional, hegelian,
# Nearest to by: during, safeguarding, rea, with, kittyhawk, for, onto, epiphany,
# Nearest to see: include, but, references, hamza, sooner, autoroute, insurance, apparel,
# Nearest to an: flutter, blob, clipperton, another, legislated, harpists, mussels, dieppe,
# Nearest to when: if, before, while, although, where, after, though, during,
# Nearest to into: through, within, across, from, adf, onto, under, tutsi,
# Nearest to one: two, six, four, seven, eight, five, three, nine,
# Nearest to two: three, four, six, eight, five, one, seven, zero,
# Nearest to more: less, rather, very, most, larger, quite, greater, faster,
# Nearest to be: been, have, become, being, remain, provide, contain, apply,
# Nearest to had: has, have, was, having, were, never, sangha, filmfare,
# Nearest to only: either, always, both, typically, necessarily, actually, regulators, sharif,
# Nearest to as: bellerophon, manitou, spheroidal, zy, gregers, preseason, internationally, approximates,
# Nearest to if: when, though, where, receives, before, then, cannot, since,
# Nearest to been: become, be, already, remained, were, begun, was, grown,
# Nearest to often: usually, sometimes, generally, commonly, typically, now, frequently, also,
# Average loss at step 62000: 2.832030
# Average loss at step 64000: 2.769359
# Average loss at step 66000: 2.763365
# Average loss at step 68000: 2.710870
# Average loss at step 70000: 2.785639
# Nearest to while: although, when, though, before, however, despite, unlike, after,
# Nearest to by: through, metalwork, onto, kittyhawk, when, while, with, bihari,
# Nearest to see: references, hamza, fulani, apparel, include, sooner, known, gardiner,
# Nearest to an: flutter, another, legislated, clipperton, roofed, dieppe, doves, electrolytes,
# Nearest to when: if, before, although, after, where, while, though, during,
# Nearest to into: through, within, across, from, adf, under, onto, tutsi,
# Nearest to one: two, eight, six, three, seven, five, four, nine,
# Nearest to two: three, four, six, eight, five, seven, one, nine,
# Nearest to more: less, very, most, quite, larger, rather, greater, highly,
# Nearest to be: been, have, being, become, is, remain, easily, refer,
# Nearest to had: have, has, was, having, never, were, filmfare, gradually,
# Nearest to only: both, either, always, all, actually, necessarily, thrift, spiritually,
# Nearest to as: bellerophon, spheroidal, bova, preseason, kashrut, rec, zy, injective,
# Nearest to if: when, though, where, before, drones, receives, after, since,
# Nearest to been: become, be, already, remained, begun, grown, were, recently,
# Nearest to often: sometimes, usually, commonly, generally, typically, now, frequently, widely,
# Average loss at step 72000: 2.794536
# Average loss at step 74000: 2.643706
# Average loss at step 76000: 2.801876
# Average loss at step 78000: 2.827160
# Average loss at step 80000: 2.775425
# Nearest to while: although, when, though, after, unlike, before, until, enters,
# Nearest to by: during, through, using, when, eyre, knife, oldies, against,
# Nearest to see: include, includes, saw, external, references, make, gardiner, tobago,
# Nearest to an: flutter, blob, mayo, roofed, dieppe, clipperton, emptying, nic,
# Nearest to when: if, although, while, before, after, where, during, though,
# Nearest to into: through, across, within, from, adf, onto, down, dubliners,
# Nearest to one: seven, two, six, four, eight, three, five, nine,
# Nearest to two: three, four, six, eight, five, seven, one, nine,
# Nearest to more: less, very, quite, most, rather, larger, greater, fairly,
# Nearest to be: become, been, remain, create, have, being, was, construct,
# Nearest to had: has, have, having, was, were, gradually, knew, never,
# Nearest to only: either, both, always, actually, approximately, necessarily, natively, mommy,
# Nearest to as: preseason, bellerophon, hwv, harboring, ventricle, dragonball, including, rec,
# Nearest to if: when, though, where, should, although, unless, cannot, before,
# Nearest to been: become, be, already, recently, remained, begun, was, grown,
# Nearest to often: sometimes, usually, commonly, generally, typically, frequently, now, also,
# Average loss at step 82000: 2.661847
# Average loss at step 84000: 2.769710
# Average loss at step 86000: 2.734918
# Average loss at step 88000: 2.752441
# Average loss at step 90000: 2.736132
# Nearest to while: although, when, though, before, unlike, or, after, quattro,
# Nearest to by: through, ard, toward, kittyhawk, obliquely, safeguarding, when, eaton,
# Nearest to see: include, but, references, includes, sooner, fulani, external, discriminatory,
# Nearest to an: clipperton, blob, flutter, legislated, nic, enclaves, mayo, fujiko,
# Nearest to when: if, while, before, after, though, where, although, because,
# Nearest to into: through, across, from, within, adf, onto, under, around,
# Nearest to one: two, six, four, eight, three, seven, five, nine,
# Nearest to two: three, six, four, seven, five, eight, one, nine,
# Nearest to more: less, most, quite, very, rather, larger, worse, faster,
# Nearest to be: become, been, being, remain, have, refer, get, construct,
# Nearest to had: has, have, having, were, was, knew, gradually, tart,
# Nearest to only: either, always, until, just, synchronisation, approximately, last, populace,
# Nearest to as: preseason, bellerophon, including, gcb, spheroidal, ibo, ajanta, suffragette,
# Nearest to if: when, though, before, where, since, although, receives, does,
# Nearest to been: become, be, remained, already, recently, grown, begun, were,
# Nearest to often: sometimes, usually, generally, typically, commonly, frequently, now, normally,
# Average loss at step 92000: 2.679274
# Average loss at step 94000: 2.724859
# Average loss at step 96000: 2.702964
# Average loss at step 98000: 2.361618
# Average loss at step 100000: 2.400230
# Nearest to while: although, though, when, before, after, unlike, began, however,
# Nearest to by: through, for, obliquely, including, when, adams, spurt, eyre,
# Nearest to see: include, references, external, includes, fulani, note, referees, called,
# Nearest to an: flutter, roofed, dieppe, raids, blob, bitstream, clipperton, hepatic,
# Nearest to when: if, before, after, while, where, though, although, because,
# Nearest to into: across, through, onto, adf, within, from, under, down,
# Nearest to one: two, three, six, five, seven, four, eight, nine,
# Nearest to two: three, five, four, six, eight, seven, nine, zero,
# Nearest to more: less, most, rather, quite, worse, faster, larger, very,
# Nearest to be: become, remain, been, being, have, were, create, construct,
# Nearest to had: has, have, having, was, knew, were, since, ever,
# Nearest to only: either, singles, deke, meet, always, scientifically, last, vault,
# Nearest to as: after, ibo, spheroidal, before, tienne, for, japh, falsificationism,
# Nearest to if: when, though, before, where, receives, after, since, hedonistic,
# Nearest to been: become, be, already, remained, were, begun, recently, grown,
# Nearest to often: sometimes, usually, typically, generally, commonly, frequently, also, still,

# %%
num_points = 1000

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=10000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
