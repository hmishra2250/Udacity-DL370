# %% [markdown]
# Deep Learning
# =============
#
# Assignment 4
# ------------
#
# Previously in `2_fullyconnected.ipynb` and `3_regularization.ipynb`, we trained fully connected networks to classify [notMNIST](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html) characters.
#
# The goal of this assignment is make the neural network convolutional.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %% [markdown]
# Reformat into a TensorFlow-friendly shape:
# - convolutions need the image data formatted as a cube (width by height by #channels)
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28, 1) (200000, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (10000, 28, 28, 1) (10000, 10)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# Let's build a small network with two convolutional layers, followed by one fully connected layer. Convolutional networks are more expensive computationally, so we'll limit its depth and number of fully connected nodes.

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 2.850859
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 1.782504
# Minibatch accuracy: 31.2%
# Validation accuracy: 49.4%
# Minibatch loss at step 100: 1.055282
# Minibatch accuracy: 62.5%
# Validation accuracy: 69.6%
# Minibatch loss at step 150: 1.396942
# Minibatch accuracy: 56.2%
# Validation accuracy: 74.4%
# Minibatch loss at step 200: 0.914393
# Minibatch accuracy: 62.5%
# Validation accuracy: 77.6%
# Minibatch loss at step 250: 0.429481
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.9%
# Minibatch loss at step 300: 0.390205
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.5%
# Minibatch loss at step 350: 0.998649
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.5%
# Minibatch loss at step 400: 0.481183
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.6%
# Minibatch loss at step 450: 0.499964
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.2%
# Minibatch loss at step 500: 0.871840
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.3%
# Minibatch loss at step 550: 1.063585
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.1%
# Minibatch loss at step 600: 0.462179
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.2%
# Minibatch loss at step 650: 0.991397
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.7%
# Minibatch loss at step 700: 0.696619
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.7%
# Minibatch loss at step 750: 0.885388
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.9%
# Minibatch loss at step 800: 1.021665
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.2%
# Minibatch loss at step 850: 0.446952
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.2%
# Minibatch loss at step 900: 0.341800
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.7%
# Minibatch loss at step 950: 0.482371
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.7%
# Minibatch loss at step 1000: 0.453269
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.4%
# Test accuracy: 88.9%

# %% [markdown]
# ---
# Problem 1
# ---------
#
# The convolutional model above uses convolutions with stride 2 to reduce the dimensionality. Replace the strides by a max pooling operation (`nn.max_pool()`) of stride 2 and kernel size 2.
#
# ---

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    pool = tf.nn.max_pool(hidden, ksize=[1,2,2,1], strides=[1,2,2,1], padding='SAME')
    conv = tf.nn.conv2d(pool, layer2_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    pool = tf.nn.max_pool(hidden, ksize=[1,2,2,1], strides=[1,2,2,1], padding='SAME')
    shape = pool.get_shape().as_list()
    print(shape)
    reshape = tf.reshape(pool, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))
# Out:
# [16, 7, 7, 16]
# [10000, 7, 7, 16]
# [10000, 7, 7, 16]

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 4.163422
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.4%
# Minibatch loss at step 50: 2.030268
# Minibatch accuracy: 25.0%
# Validation accuracy: 36.7%
# Minibatch loss at step 100: 1.173907
# Minibatch accuracy: 68.8%
# Validation accuracy: 62.7%
# Minibatch loss at step 150: 1.047236
# Minibatch accuracy: 56.2%
# Validation accuracy: 68.3%
# Minibatch loss at step 200: 0.810297
# Minibatch accuracy: 75.0%
# Validation accuracy: 76.5%
# Minibatch loss at step 250: 0.542067
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.8%
# Minibatch loss at step 300: 0.571049
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.0%
# Minibatch loss at step 350: 0.890173
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.2%
# Minibatch loss at step 400: 0.513948
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.0%
# Minibatch loss at step 450: 0.341944
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.1%
# Minibatch loss at step 500: 0.688224
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.0%
# Minibatch loss at step 550: 1.036529
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 600: 0.395581
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.1%
# Minibatch loss at step 650: 0.931773
# Minibatch accuracy: 68.8%
# Validation accuracy: 82.0%
# Minibatch loss at step 700: 0.623311
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.6%
# Minibatch loss at step 750: 0.871678
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.4%
# Minibatch loss at step 800: 1.021408
# Minibatch accuracy: 68.8%
# Validation accuracy: 83.5%
# Minibatch loss at step 850: 0.544716
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.8%
# Minibatch loss at step 900: 0.280557
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.8%
# Minibatch loss at step 950: 0.679899
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.1%
# Minibatch loss at step 1000: 0.308318
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.7%
# Test accuracy: 90.0%

# %% [markdown]
# ---
# Problem 2
# ---------
#
# Try to get the best performance you can using a convolutional net. Look for example at the classic [LeNet5](http://yann.lecun.com/exdb/lenet/) architecture, adding Dropout, and/or adding learning rate decay.
#
# ---

# %%
batch_size = 64
patch_size = 5
depth = 32
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    pool = tf.nn.avg_pool(hidden, ksize=[1,2,2,1], strides=[1,2,2,1], padding='SAME')
    conv = tf.nn.conv2d(pool, layer2_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    pool = tf.nn.avg_pool(hidden, ksize=[1,2,2,1], strides=[1,2,2,1], padding='SAME')
    shape = pool.get_shape().as_list()
    print(shape)
    reshape = tf.reshape(pool, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

num_steps = 10001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 500 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# [64, 7, 7, 32]
# [10000, 7, 7, 32]
# [10000, 7, 7, 32]
# Initialized
# Minibatch loss at step 0: 5.824993
# Minibatch accuracy: 6.2%
# Validation accuracy: 9.7%
# Minibatch loss at step 500: 0.703758
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 1000: 0.408750
# Minibatch accuracy: 89.1%
# Validation accuracy: 85.4%
# Minibatch loss at step 1500: 0.242372
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.6%
# Minibatch loss at step 2000: 0.527866
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.3%
# Minibatch loss at step 2500: 0.646556
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.9%
# Minibatch loss at step 3000: 0.309477
# Minibatch accuracy: 92.2%
# Validation accuracy: 87.8%
# Minibatch loss at step 3500: 0.153755
# Minibatch accuracy: 95.3%
# Validation accuracy: 88.4%
# Minibatch loss at step 4000: 0.432996
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.6%
# Minibatch loss at step 4500: 0.262458
# Minibatch accuracy: 95.3%
# Validation accuracy: 88.7%
# Minibatch loss at step 5000: 0.250018
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.2%
# Minibatch loss at step 5500: 0.394233
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.3%
# Minibatch loss at step 6000: 0.351470
# Minibatch accuracy: 85.9%
# Validation accuracy: 89.1%
# Minibatch loss at step 6500: 0.370727
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.2%
# Minibatch loss at step 7000: 0.102480
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.3%
# Minibatch loss at step 7500: 0.197446
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.5%
# Minibatch loss at step 8000: 0.289213
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.8%
# Minibatch loss at step 8500: 0.414156
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.0%
# Minibatch loss at step 9000: 0.313443
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.5%
# Minibatch loss at step 9500: 0.216289
# Minibatch accuracy: 95.3%
# Validation accuracy: 90.0%
# Minibatch loss at step 10000: 0.169348
# Minibatch accuracy: 95.3%
# Validation accuracy: 90.1%
# Test accuracy: 95.3%

# %%
batch_size = 64
patch_size = 5
depth = 32
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=np.sqrt(2.0 / (image_size * image_size))))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=np.sqrt(2.0 / (image_size * image_size))))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=np.sqrt(2.0 / (image_size * image_size))))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=np.sqrt(2.0 / (image_size * image_size))))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data, train=False):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    pool = tf.nn.avg_pool(hidden, ksize=[1,2,2,1], strides=[1,2,2,1], padding='SAME')
    conv = tf.nn.conv2d(pool, layer2_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    pool = tf.nn.max_pool(hidden, ksize=[1,2,2,1], strides=[1,2,2,1], padding='SAME')
    shape = pool.get_shape().as_list()
    print(shape)
    reshape = tf.reshape(pool, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    if train:
        hidden = tf.nn.dropout(hidden, keep_prob=0.3)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

num_steps = 20001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 500 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# [64, 7, 7, 32]
# [10000, 7, 7, 32]
# [10000, 7, 7, 32]
# Initialized
# Minibatch loss at step 0: 2.396194
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 500: 0.716294
# Minibatch accuracy: 78.1%
# Validation accuracy: 82.4%
# Minibatch loss at step 1000: 0.488117
# Minibatch accuracy: 89.1%
# Validation accuracy: 85.0%
# Minibatch loss at step 1500: 0.231508
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.6%
# Minibatch loss at step 2000: 0.493171
# Minibatch accuracy: 85.9%
# Validation accuracy: 87.4%
# Minibatch loss at step 2500: 0.674689
# Minibatch accuracy: 78.1%
# Validation accuracy: 87.8%
# Minibatch loss at step 3000: 0.364573
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.0%
# Minibatch loss at step 3500: 0.183410
# Minibatch accuracy: 95.3%
# Validation accuracy: 88.6%
# Minibatch loss at step 4000: 0.405490
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.6%
# Minibatch loss at step 4500: 0.272295
# Minibatch accuracy: 95.3%
# Validation accuracy: 89.3%
# Minibatch loss at step 5000: 0.266061
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.2%
# Minibatch loss at step 5500: 0.364884
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.8%
# Minibatch loss at step 6000: 0.284050
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.8%
# Minibatch loss at step 6500: 0.336731
# Minibatch accuracy: 85.9%
# Validation accuracy: 89.7%
# Minibatch loss at step 7000: 0.104319
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.0%
# Minibatch loss at step 7500: 0.185874
# Minibatch accuracy: 95.3%
# Validation accuracy: 90.0%
# Minibatch loss at step 8000: 0.333703
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.3%
# Minibatch loss at step 8500: 0.473503
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.2%
# Minibatch loss at step 9000: 0.263206
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.2%
# Minibatch loss at step 9500: 0.217754
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.3%
# Minibatch loss at step 10000: 0.139210
# Minibatch accuracy: 95.3%
# Validation accuracy: 90.5%
# Minibatch loss at step 10500: 0.108445
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.6%
# Minibatch loss at step 11000: 0.405528
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.5%
# Minibatch loss at step 11500: 0.294593
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.6%
# Minibatch loss at step 12000: 0.248036
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.7%
# Minibatch loss at step 12500: 0.276134
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.5%
# Minibatch loss at step 13000: 0.220214
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.6%
# Minibatch loss at step 13500: 0.338955
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.8%
# Minibatch loss at step 14000: 0.395957
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.8%
# Minibatch loss at step 14500: 0.346205
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.8%
# Minibatch loss at step 15000: 0.146459
# Minibatch accuracy: 95.3%
# Validation accuracy: 91.0%
# Minibatch loss at step 15500: 0.373725
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.8%
# Minibatch loss at step 16000: 0.327357
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.9%
# Minibatch loss at step 16500: 0.327153
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.8%
# Minibatch loss at step 17000: 0.296966
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.8%
# Minibatch loss at step 17500: 0.291693
# Minibatch accuracy: 89.1%
# Validation accuracy: 91.3%
# Minibatch loss at step 18000: 0.232083
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.8%
# Minibatch loss at step 18500: 0.359376
# Minibatch accuracy: 87.5%
# Validation accuracy: 91.0%
# Minibatch loss at step 19000: 0.154676
# Minibatch accuracy: 96.9%
# Validation accuracy: 91.1%
# Minibatch loss at step 19500: 0.327577
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.2%
# Minibatch loss at step 20000: 0.320832
# Minibatch accuracy: 89.1%
# Validation accuracy: 91.2%
# Test accuracy: 96.3%

# %%
batch_size = 64
patch_size = 5
depth = 32
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=np.sqrt(2.0 / (image_size * image_size))))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=np.sqrt(2.0 / (image_size * image_size))))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=np.sqrt(2.0 / (image_size * image_size))))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=np.sqrt(2.0 / (image_size * image_size))))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data, train=False):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    pool = tf.nn.avg_pool(hidden, ksize=[1,2,2,1], strides=[1,2,2,1], padding='SAME')
    conv = tf.nn.conv2d(pool, layer2_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    pool = tf.nn.avg_pool(hidden, ksize=[1,2,2,1], strides=[1,2,2,1], padding='SAME')
    shape = pool.get_shape().as_list()
    print(shape)
    reshape = tf.reshape(pool, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    if train:
        hidden = tf.nn.dropout(hidden, keep_prob=0.3)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

num_steps = 20001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 500 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# [64, 7, 7, 32]
# [10000, 7, 7, 32]
# [10000, 7, 7, 32]
# Initialized
# Minibatch loss at step 0: 2.481456
# Minibatch accuracy: 4.7%
# Validation accuracy: 10.0%
# Minibatch loss at step 500: 0.806655
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.8%
# Minibatch loss at step 1000: 0.572952
# Minibatch accuracy: 85.9%
# Validation accuracy: 84.1%
# Minibatch loss at step 1500: 0.291002
# Minibatch accuracy: 90.6%
# Validation accuracy: 85.1%
# Minibatch loss at step 2000: 0.484176
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.2%
# Minibatch loss at step 2500: 0.797123
# Minibatch accuracy: 76.6%
# Validation accuracy: 86.7%
# Minibatch loss at step 3000: 0.313286
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.1%
# Minibatch loss at step 3500: 0.152538
# Minibatch accuracy: 95.3%
# Validation accuracy: 87.7%
# Minibatch loss at step 4000: 0.471414
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.2%
# Minibatch loss at step 4500: 0.299623
# Minibatch accuracy: 92.2%
# Validation accuracy: 88.4%
# Minibatch loss at step 5000: 0.272919
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.5%
# Minibatch loss at step 5500: 0.395781
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.9%
# Minibatch loss at step 6000: 0.329109
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.0%
# Minibatch loss at step 6500: 0.412399
# Minibatch accuracy: 85.9%
# Validation accuracy: 89.1%
# Minibatch loss at step 7000: 0.131765
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.2%
# Minibatch loss at step 7500: 0.179797
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.6%
# Minibatch loss at step 8000: 0.330590
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.9%
# Minibatch loss at step 8500: 0.396308
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.9%
# Minibatch loss at step 9000: 0.316697
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.8%
# Minibatch loss at step 9500: 0.244450
# Minibatch accuracy: 95.3%
# Validation accuracy: 89.8%
# Minibatch loss at step 10000: 0.155566
# Minibatch accuracy: 95.3%
# Validation accuracy: 90.0%
# Minibatch loss at step 10500: 0.140654
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.1%
# Minibatch loss at step 11000: 0.454604
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.3%
# Minibatch loss at step 11500: 0.355300
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.1%
# Minibatch loss at step 12000: 0.296903
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.4%
# Minibatch loss at step 12500: 0.320689
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.5%
# Minibatch loss at step 13000: 0.222681
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.4%
# Minibatch loss at step 13500: 0.307001
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.5%
# Minibatch loss at step 14000: 0.416337
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.6%
# Minibatch loss at step 14500: 0.355889
# Minibatch accuracy: 85.9%
# Validation accuracy: 90.7%
# Minibatch loss at step 15000: 0.140226
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.7%
# Minibatch loss at step 15500: 0.419600
# Minibatch accuracy: 84.4%
# Validation accuracy: 90.8%
# Minibatch loss at step 16000: 0.281715
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.7%
# Minibatch loss at step 16500: 0.363287
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.8%
# Minibatch loss at step 17000: 0.361800
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.9%
# Minibatch loss at step 17500: 0.276172
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.8%
# Minibatch loss at step 18000: 0.252930
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.7%
# Minibatch loss at step 18500: 0.410446
# Minibatch accuracy: 85.9%
# Validation accuracy: 91.0%
# Minibatch loss at step 19000: 0.169078
# Minibatch accuracy: 95.3%
# Validation accuracy: 90.9%
# Minibatch loss at step 19500: 0.343370
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.9%
# Minibatch loss at step 20000: 0.318184
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.3%
# Test accuracy: 96.3%
